# %% [markdown]
# ### What is a Pull Request?
#
# A Pull Request, usually called PR, is a request to merge changes from one branch into another branch.
# Other team members can check your code before it goes into the `main` project.

# %% [markdown]
# + **go to working directory**
# ``` bash
# cd /d E:/data/Documents/Data_Engineering/Module2_Github/github-practice
# ```
# + **check branch**
# ``` bash
# git branch
# ```
# + **go to github and create dummy repository clone_example**
# ``` bash
# git clone https://github.com/Sawan8/clone_example.git
# ```
# + **go to folder**
# ``` bash
# cd clone_example
# ```
#
# ``` bash
# git remote -v
# git checkout main
# git pull origin main
# git checkout -b feature/abc
# ```
#
# + **do some changes in branch through vs code**
#
# + **now commit the changes**
#
# ``` bash
# git status
# git add .
# git commit -m "new change"
# ```
#
# + **now push the changes to Github**
#
# ``` bash
# git push -u origin feature/abc
#
# ```
# <br> It does two important jobs:
#
# + Uploads your local branch feature/abc to GitHub.
# + Sets tracking between your local branch and the GitHub branch.
#
# + **Create Pull Request on GitHub**
#
# <br> *On GitHub:*
#
# <br> Open your repository.
# <br> You may see a button: Compare & pull request.
# <br> Click it.
# <br> Check the branch comparison.

# %% [markdown]
# **We can add Multiple Reviewers for PR review**

# %% [markdown]
# ## Pull Request Review Process

# %% [markdown]
# ![image.png](attachment:e6b3a42e-872e-4693-9014-757dd3b09788.png)
