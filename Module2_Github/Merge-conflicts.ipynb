# %% [markdown]
# ### Why Git has Merge Conflicts?

# %% [markdown]
# If both branches changed different files or different lines, Git can merge automatically.
#
# But if both branches changed the same line in the same file, Git gets confused and asks the developer to decide.

# %% [markdown]
# + **go to working directory**
# ``` bash
# cd /d E:/data/Documents/Data_Engineering/Module2_Github/github-practice
# ```
# + **check branch**
# ``` bash
# git branch
# ```
# + **check status before any step**
# ``` bash
# git status
# ```
# + **create new branch and switch to it**
# ``` bash
# git checkout -b feature-contact-page
# ```
# + **now again check in which branch we are now**
# ``` bash
# git branch
# ```
# + **go to VS code and create new conflict_demo.py file**
#
# + **now commit the changes**
#
# ``` bash
# git status
# git add .
# git commit -m "new change"
# ```
# + **View branch history**
#
# ``` bash
# git log --oneline
# ```
#
# + **go back to main**
# ``` bash
# git checkout main
# ```
#
# + **go to VS code and create conflict_Demo.py and edit same line**
#
# + **now commit your changes**
#
# ``` bash
# git status
# git add .
# git commit -m "new change"
# ```
#
# + **now merge the commit from feature-contact-page to main**
# ``` bash
# git merge feature-contact-page
#
# ```
#
# <span style="color:blue">Note: go to vs code and we can see conflicts</span>
#
# ![image.png](attachment:e02ee4ff-1303-4f88-8932-a12ea8479e36.png)
#
#
# + **choose any of the change option**
#
# + **now commit your changes**
#
# ``` bash
# git status
# git add .
# git commit -m "resolved conflicts"
# ```
#
# + **now merge the changes again**
# ``` bash
# git merge feature-contact-page
#
# ```
