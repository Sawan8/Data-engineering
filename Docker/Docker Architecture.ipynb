# %% [markdown]
# #### What is Docker Architecture?
#
# Docker architecture means the internal structure of Docker: how Docker receives our command, how it builds or downloads images, and how it creates containers from those images.

# %% [markdown]
# ![image.png](attachment:97d74124-c416-4125-8ed1-b4527ffb6f9a.png)
